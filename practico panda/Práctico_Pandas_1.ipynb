# %% [markdown]
# ### Bienvenidos al práctico de PANDAS Parte 1.
#
# Durante las siguientes clases estaremos analizando diferentes juegos de datos utilizando la librería PANDAS 🐼
#
# https://github.com/pandas-dev/pandas
#
#
# Primero conectemos la libreta a google drive para poder cargar los datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##### Vamos a importar las librerías

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

f"Esta es la versión de pandas instalada en el colab {pd.__version__}" #Noten que PANDAS ya viene instalado en google colab. En local deben primero instalarlo con su gestor de paquetes de confianza
# Out:
# 'Esta es la versión de pandas instalada en el colab 2.2.2'

# %% [markdown]
# ##### Cargando los datos

# %% [markdown]
# 🚀  Carguemos los datos en un dataframe
#
# Trabajaremos con Pokemon
#
# ![https _s3-ap-southeast-2.amazonaws.com_vms-tv-images-prod_2017_02_58621_POKE_Pokemon_1920.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# >>> Pokémon <<<
#
# <li>Criatura ficticia del universo de la franquicia Pokémon (Nintendo) </li>
#
# <li> Hay muchos tipos de Pokémon, cada uno con habilidades, y estadísticas distintas: Hit points, Attack, Defense, etc.  <li>

# %% [markdown]
# Por más info https://en.wikipedia.org/wiki/Pok%C3%A9mon

# %%
def get_my_data():
  data_path = '/content/drive/MyDrive/DIPLOMA 2025/Pandas/data/' #Cambiar esta línea para donde están tus datos
  pokemon_path = data_path + 'p1_pokemon.csv'
  pokemon = pd.read_csv(pokemon_path)  #https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
  return pokemon

# %%
pokemon =  get_my_data()

# %% [markdown]
# ##### Pandas permite cargar varios tipos de archivos a DataFrame
#
#
# <li> CSV </li>
# <li> excel </li>
# <li> sql </li>
# <li> parquet </li>
# <li> pickle </li>
# <li> json </li>
# <li> xml </li>
# <li> del porta papeles </li>

# %% [markdown]
# ### Obteniendo información básica

# %%
### Obteniendo información del bojeto
type(pokemon)
# Out:
# pandas.core.frame.DataFrame

# %%
### Obteniendo información del objeto

pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
nrows , ncols = pokemon.shape
f"El dataset tiene {nrows} filas y {ncols} columnas"
# Out:
# 'El dataset tiene 800 filas y 13 columnas'

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
pokemon_totales = len(pokemon['Name'].unique()) #  pokemon['Name'].count()
tipo_1 = pokemon['Type 1'].count()
tipo_2 = pokemon['Type 2'].count()
print(f"Hay un total de {pokemon_totales}, {tipo_1} tienen clase tipo 1 y  {tipo_2} tienen  tipo 2")
# Out:
# Hay un total de 800, 800 tienen clase tipo 1 y  414 tienen  tipo 2

# %%
pokemon.columns #Accediendo a las columnas
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon.index, len(pokemon.index) #Accediendo a los indices
# Out:
# (RangeIndex(start=0, stop=800, step=1), 800)

# %%
pokemon.dtypes # Otra forma de acceder a los dtypes
#https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html#basics-dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
 ### Obtenemos información general de cada variable
pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
pokemon.describe(percentiles=[0.1,0.5,0.9]) ### Se puede fijar diferentes percentiles. Prueba [x/10 for x in range(10)]""
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 10%     73.900000  288.00000   40.000000   40.000000   40.000000   35.000000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 90%    651.100000  600.00000  100.000000  125.000000  115.000000  120.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 10%     40.000000   30.000000     1.00000
# ...

# %% [markdown]
# ### Navegando por el dataset

# %% [markdown]
# ##### Selección de cabeza , cola y aleatoria

# %%
### Veamos la "Cabeza" del dataset. Se puede pasar la cantidad de filas que deseamos ver
pokemon.head(2)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False

# %%
### Veamos la "Cola" del dataset. Se puede pasar la cantidad de filas que deseamos ver
pokemon.tail(10)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 790  714               Noibat   Flying  Dragon    245   40      30       35
# 791  715              Noivern   Flying  Dragon    535   85      70       80
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# ...

# %%
##### Se puede hacer un muestreo de un dataset

pokemon.sample(8) # Pueden elegirse n elementos o samplear una fracción del dataset / frac = x.x
# Out:
#        #       Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 218  203  Girafarig    Normal  Psychic    455   70      80       65       90
# 157  145     Zapdos  Electric   Flying    580   90      90       85      125
# 55    50    Diglett    Ground      NaN    265   10      55       25       35
# 490  442  Spiritomb     Ghost     Dark    485   50      92      108       92
# 495  446   Munchlax    Normal      NaN    390  135      85       40       40
# 98    91   Cloyster     Water      Ice    525   50      95      180       85
# 324  300     Skitty    Normal      NaN    260   50      45       45       35
# 6      6  Charizard      Fire   Flying    534   78      84       78      109
#
#      Sp. Def  Speed  Generation  Legendary
# 218       65     85           2      False
# 157       90    100           1       True
# 55        45     95           1      False
# 490      108     35           4      False
# 495       85      5           4      False
# ...

# %% [markdown]
# ##### Selección por label, index, columna, etc

# %%
### Selecciona solo la fila 5
pokemon.iloc[5]
# Out:
# #                      5
# Name          Charmeleon
# Type 1              Fire
# Type 2               NaN
# Total                405
# HP                    58
# Attack                64
# Defense               58
# Sp. Atk               80
# Sp. Def               65
# Speed                 80
# Generation             1
# Legendary          False
# Name: 5, dtype: object

# %%
#Puedo buscar por el nombre del indice tmb. (En la primera funcion se cambia el indice del dataframe a "Name" y luego se busca por ahí)
pokemon.set_index('Name').loc['Pikachu']
# Out:
# #                   25
# Type 1        Electric
# Type 2             NaN
# Total              320
# HP                  35
# Attack              55
# Defense             40
# Sp. Atk             50
# Sp. Def             50
# Speed               90
# Generation           1
# Legendary        False
# Name: Pikachu, dtype: object

# %%
#Selecciona las filas 5 a 19
pokemon.iloc[5:20]
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# 11   9                  Blastoise  Water     NaN    530  79      83      100
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 13  10                   Caterpie    Bug     NaN    195  45      30       35
# 14  11                    Metapod    Bug     NaN    205  50      20       55
# 15  12                 Butterfree    Bug  Flying    395  60      45       50
# ...

# %%
# Seleccionando columnas
pokemon[['HP','Speed']] ###Noten los doble corchetes
# Out:
#      Total  HP
# 0      318  45
# 1      405  60
# 2      525  80
# 3      625  80
# 4      309  39
# ..     ...  ..
# 795    600  50
# 796    700  50
# 797    600  80
# 798    680  80
# 799    600  80
#
# [800 rows x 2 columns]

# %% [markdown]
# ##### Zen of python
#
#
# [...] In the face of ambiguity, refuse the temptation to guess.
#
# ***There should be one-- and preferably only one --obvious way to do it.***
#
#
#
#
#
#
#
#
#
# https://peps.python.org/pep-0020/

# %%
print(pokemon.loc[0,'Name'],"-", pokemon.loc[0]['Name'],"-", pokemon['Name'].loc[0],"-",pokemon['Name'].values[0])
pokemon.loc[0,'Name'] == pokemon.loc[0]['Name'] == pokemon['Name'].loc[0] == pokemon['Name'].values[0]
# Out:
# Bulbasaur - Bulbasaur - Bulbasaur - Bulbasaur
# True

# %%
pokemon['Total'] == pokemon.HP
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 795    True
# 796    True
# 797    True
# 798    True
# 799    True
# Name: HP, Length: 800, dtype: bool

# %% [markdown]
# ### Selecciones por dytpe

# %%
# Se pueden seleccionar columnas basados en su dtype
pokemon.select_dtypes(exclude=['int64'])
# Out:
#                       Name   Type 1  Type 2  Legendary
# 0                Bulbasaur    Grass  Poison      False
# 1                  Ivysaur    Grass  Poison      False
# 2                 Venusaur    Grass  Poison      False
# 3    VenusaurMega Venusaur    Grass  Poison      False
# 4               Charmander     Fire     NaN      False
# ..                     ...      ...     ...        ...
# 795                Diancie     Rock   Fairy       True
# 796    DiancieMega Diancie     Rock   Fairy       True
# 797    HoopaHoopa Confined  Psychic   Ghost       True
# 798     HoopaHoopa Unbound  Psychic    Dark       True
# 799              Volcanion     Fire   Water       True
#
# [800 rows x 4 columns]

# %% [markdown]
# ##### Se pueden hacer queries del estilo SQL en DataFrames

# %%
pokemon.query('Name.str.contains("Bulb")', engine='python') #
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Generation  Legendary
# 0     45           1      False

# %%
query_pokemon = pokemon.query('Attack > 80 and Defense < 40 ', engine='python')['Name'].to_list() # Podemos acceder a los valroes de las columnas
query_pokemon
# Out:
# ['Carvanha', 'DeoxysAttack Forme']

# %%
### Se puede iterar por las filas gracias a la función iterrows()
for index, row in pokemon[:5].iterrows():
  print(index,row['Name'],row['HP'])
# Out:
# 0 Bulbasaur 45
# 1 Ivysaur 60
# 2 Venusaur 80
# 3 VenusaurMega Venusaur 80
# 4 Charmander 39

# %% [markdown]
# ### Por valor en celda

# %%
pokemon['HP']==100
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: HP, Length: 800, dtype: bool

# %%
pokemon[pokemon['HP']==100]
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 165  151                      Mew  Psychic       NaN    600  100     100
# 178  164                  Noctowl   Normal    Flying    442  100      50
# 199  184                Azumarill    Water     Fairy    420  100      50
# 221  206                Dunsparce   Normal       NaN    415  100      70
# 239  221                Piloswine      Ice    Ground    450  100     100
# 264  245                  Suicune    Water       NaN    580  100      75
# 267  248                Tyranitar     Rock      Dark    600  100     134
# 268  248  TyranitarMega Tyranitar     Rock      Dark    700  100     164
# 271  251                   Celebi  Psychic     Grass    600  100     100
# 282  260                 Swampert    Water    Ground    535  100     110
# 283  260    SwampertMega Swampert    Water    Ground    635  100     150
# 346  317                   Swalot   Poison       NaN    467  100      73
# ...

# %%
pokemon[~pokemon['Type 2'].isna()] # ~ Condiciòn reversa, negación
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ### Modificando DataFrames

# %%
pokemon =  get_my_data()  #
df_copy = pokemon.copy()
df_no_copy = pokemon

# %%
pokemon['Total'] == pokemon[['HP','Speed','Attack','Defense','Sp. Atk','Sp. Def']].sum(axis=1) #'columns'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 795    True
# 796    True
# 797    True
# 798    True
# 799    True
# Length: 800, dtype: bool

# %%
pokemon['Total'] = pokemon[['HP','Speed','Attack','Defense','Sp. Atk','Sp. Def']].sum(axis='columns') #'columns':1 - 'rows': 0

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
cols_to_drop = ['HP','Speed']
df_copy.drop(columns=cols_to_drop,inplace=True)  ### Inplace indica que se va a modificar el dataframe
df_copy.columns, pokemon.columns
# Out:
# (Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'Attack', 'Defense',
#         'Sp. Atk', 'Sp. Def', 'Generation', 'Legendary'],
#        dtype='object'),
#  Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#         'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#        dtype='object'))

# %%
cols_to_drop = ['HP','Speed']
df_no_copy.drop(columns=cols_to_drop,inplace=True)
df_no_copy.columns  , pokemon.columns
# Out:
# (Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'Attack', 'Defense',
#         'Sp. Atk', 'Sp. Def', 'Generation', 'Legendary'],
#        dtype='object'),
#  Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'Attack', 'Defense',
#         'Sp. Atk', 'Sp. Def', 'Generation', 'Legendary'],
#        dtype='object'))

# %%
who ### Con who podemos ver que objetos tenenemos guardados en memoria
# Out:
# No variables match your requested type.

# %%
del  cols_to_drop

# %%
who
# Out:
# df_copy	 df_no_copy	 drive	 get_my_data	 index	 ncols	 np	 nrows	 pd
# plt	 pokemon	 pokemon_totales	 query_pokemon	 row	 sns	 tipo_1	 tipo_2

# %%
#Borrando datos
pokemon =  get_my_data() #o pokemon = df_copy.copy()
pokemon.dropna()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Llenando datos faltantes (imputar)
pokemon =  get_my_data() #o pokemon = df_copy.copy()
pokemon['Type 2'].fillna('SIN DATO',inplace=True) #Aplica a todo el dataframe
pokemon['Type 2'].value_counts().plot(kind='bar')
plt.title("DIstribucion de Columna type 2")
plt.show()
# Out:
# <ipython-input-39-2262c2c2cc65>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   pokemon['Type 2'].fillna('SIN DATO',inplace=True) #Aplica a todo el dataframe

# %%
pokemon['Total'].astype('string') + " ahora sos string"  #Diferentes tipos de dtypes soportados
# Out:
# 0      318 ahora sos string
# 1      405 ahora sos string
# 2      525 ahora sos string
# 3      625 ahora sos string
# 4      309 ahora sos string
#                ...
# 795    600 ahora sos string
# 796    700 ahora sos string
# 797    600 ahora sos string
# 798    680 ahora sos string
# 799    600 ahora sos string
# Name: Total, Length: 800, dtype: string

# %% [markdown]
# ##### Dos formas de modificar celdas en el DataFrame

# %%
pokemon.at[0,'Name'] = 'OTRO NOMBRE'
pokemon.head()
# Out:
#    #                   Name Type 1    Type 2  Total  HP  Attack  Defense  \
# 0  1            OTRO NOMBRE  Grass    Poison    318  45      49       49
# 1  2                Ivysaur  Grass    Poison    405  60      62       63
# 2  3               Venusaur  Grass    Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass    Poison    625  80     100      123
# 4  4             Charmander   Fire  SIN DATO    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon.loc[0,'Name'] = 'OTRO NOMBRE'
pokemon.head()
# Out:
#    #                   Name Type 1    Type 2  Total  HP  Attack  Defense  \
# 0  1            OTRO NOMBRE  Grass    Poison    318  45      49       49
# 1  2                Ivysaur  Grass    Poison    405  60      62       63
# 2  3               Venusaur  Grass    Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass    Poison    625  80     100      123
# 4  4             Charmander   Fire  SIN DATO    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
### Crear nuevas columnas /  Broadcasting
pokemon['NUEVA_COLUMNA_0'] = pokemon['Attack'] - 80
pokemon['NUEVA_COLUMNA_1'] = pokemon['Attack'] **2 + pokemon['Speed']
pokemon['NUEVA_COLUMNA_2'] = pokemon['Type 1'] + "-" + pokemon['Type 2']
pokemon.head()
# Out:
#    #                   Name Type 1    Type 2  Total  HP  Attack  Defense  \
# 0  1            OTRO NOMBRE  Grass    Poison    318  45      49       49
# 1  2                Ivysaur  Grass    Poison    405  60      62       63
# 2  3               Venusaur  Grass    Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass    Poison    625  80     100      123
# 4  4             Charmander   Fire  SIN DATO    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  NUEVA_COLUMNA_0  \
# 0       65       65     45           1      False              -31
# 1       80       80     60           1      False              -18
# 2      100      100     80           1      False                2
# 3      122      120     80           1      False               20
# 4       60       50     65           1      False              -28
#
#    NUEVA_COLUMNA_1 NUEVA_COLUMNA_2
# 0             2446    Grass-Poison
# 1             3904    Grass-Poison
# ...

# %% [markdown]
# ### Apliquemos una función

# %%
pokemon.nunique()
# Out:
# #                  721
# Name               800
# Type 1              18
# Type 2              19
# Total              200
# HP                  94
# Attack             111
# Defense            103
# Sp. Atk            105
# Sp. Def             92
# Speed              108
# Generation           6
# Legendary            2
# NUEVA_COLUMNA_0    111
# NUEVA_COLUMNA_1    590
# NUEVA_COLUMNA_2    154
# dtype: int64

# %%
pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
def is_organic(x):
  """Retorna si un pokemon es òrganico dado su typo 1"""
  organics = ['Grass','Bug','Normal','Poison','Ground']
  return x in organics

# %%
pokemon['organic'] = pokemon['Type 1'].apply(lambda x: is_organic(x))

# %%
pokemon.head()
# Out:
#    #                   Name Type 1    Type 2  Total  HP  Attack  Defense  \
# 0  1            OTRO NOMBRE  Grass    Poison    318  45      49       49
# 1  2                Ivysaur  Grass    Poison    405  60      62       63
# 2  3               Venusaur  Grass    Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass    Poison    625  80     100      123
# 4  4             Charmander   Fire  SIN DATO    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  NUEVA_COLUMNA_0  \
# 0       65       65     45           1      False              -31
# 1       80       80     60           1      False              -18
# 2      100      100     80           1      False                2
# 3      122      120     80           1      False               20
# 4       60       50     65           1      False              -28
#
#    NUEVA_COLUMNA_1 NUEVA_COLUMNA_2  organic
# 0             2446    Grass-Poison     True
# ...

# %%
#Visualicemos estos resultados
#Listados de colores https://matplotlib.org/stable/gallery/color/named_colors.html

pokemon['organic'].value_counts().plot(kind='bar',color=['lightgrey','forestgreen']) #normalize = True

plt.title('Cantidad de organicos vs no-organicos')
plt.ylabel('Cantidad pokemon')
plt.show()

# %% [markdown]
# ##### Map

# %%
generation_dict = {1:'Viejo',6:'Nuevo'}
pokemon['Generation'].map(generation_dict).unique()
# Out:
# array(['Viejo', nan, 'Nuevo'], dtype=object)

# %%
pokemon =  get_my_data()

# %%
#### La función map difiere de apply al aplicarse al todo el dataset
pokemon
otro = pokemon.map(lambda x: str(x) + "+ pasó la funcion")
otro.head(2)
# Out:
#                     #                        Name                  Type 1  \
# 0  1+ pasó la funcion  Bulbasaur+ pasó la funcion  Grass+ pasó la funcion
# 1  2+ pasó la funcion    Ivysaur+ pasó la funcion  Grass+ pasó la funcion
#
#                     Type 2                 Total                   HP  \
# 0  Poison+ pasó la funcion  318+ pasó la funcion  45+ pasó la funcion
# 1  Poison+ pasó la funcion  405+ pasó la funcion  60+ pasó la funcion
#
#                 Attack              Defense              Sp. Atk  \
# 0  49+ pasó la funcion  49+ pasó la funcion  65+ pasó la funcion
# 1  62+ pasó la funcion  63+ pasó la funcion  80+ pasó la funcion
#
#                Sp. Def                Speed          Generation  \
# 0  65+ pasó la funcion  45+ pasó la funcion  1+ pasó la funcion
# 1  80+ pasó la funcion  60+ pasó la funcion  1+ pasó la funcion
#
#                 Legendary
# 0  False+ pasó la funcion
# 1  False+ pasó la funcion

# %%
### Si map falla es porque no existe en la versión instalada en el colab. Hay que actualizarla. Correr el comando de abajo, reiniciar el entorno y volver a correr la libreta

# !pip install pandas -U

### https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.map.html
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 54.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# ...

# %% [markdown]
# ### Generar rangos

# %%
pokemon['Attack']
# Out:
# 0       49
# 1       62
# 2       82
# 3      100
# 4       52
#       ...
# 795    100
# 796    160
# 797    110
# 798    160
# 799    110
# Name: Attack, Length: 800, dtype: int64

# %%
np.where(pokemon['Attack']<40,"Débil",
         np.where(pokemon['Attack']>100,"Fuerte",
         "Medio")
         )[:20] #Crea un array np
# Out:
# array(['Medio', 'Medio', 'Medio', 'Medio', 'Medio', 'Medio', 'Medio',
#        'Fuerte', 'Fuerte', 'Medio', 'Medio', 'Medio', 'Fuerte', 'Débil',
#        'Débil', 'Medio', 'Débil', 'Débil', 'Medio', 'Fuerte'], dtype='<U6')

# %%
# Asingar a columna
pokemon['rango_ataque'] = np.where(pokemon['Attack']<40,"Débil",
         np.where(pokemon['Attack']>100,"Fuerte",
         "Medio")
         )
pokemon['rango_ataque'].value_counts()
# Out:
# rango_ataque
# Medio     566
# Fuerte    170
# Débil      64
# Name: count, dtype: int64

# %%
pokemon['Q_ATAQUE'] = pd.qcut(pokemon['Attack'],q=4,labels=['Bajo','Medio-Bajo','Medio-Alto','Alto'])
pokemon['Q_ATAQUE'].value_counts()
# Out:
# Q_ATAQUE
# Medio-Alto    221
# Bajo          215
# Medio-Bajo    194
# Alto          170
# Name: count, dtype: int64

# %%
##### Podemos cambiar nombre a las columnas
to_rename = {'Name':'nombre',
             'Type 1':'tipo_1',
             'Type 2':'tipo_2',
             'Total':'total',
             'HP':'puntos_de_vida',
             'Attack':'ataque',
             'Defense':'defensa',
             'Sp. Atk':'ataque_especial',
             'Sp. Def':'defensa_especial',
             'Speed':'velocidad',
             'Generation':'generacion',
             'Legendary':'legendario'}

pokemon = get_my_data()
pokemon.rename(to_rename,axis=1,inplace=True) #### <--- axis = 1 marca que quiero realizarlo sobre las columnas. Axis = 0 marca que quiero realizarlo sobre los índices
pokemon = pokemon[to_rename.values()]
pokemon.head(2)
# Out:
#       nombre tipo_1  tipo_2  total  puntos_de_vida  ataque  defensa  \
# 0  Bulbasaur  Grass  Poison    318              45      49       49
# 1    Ivysaur  Grass  Poison    405              60      62       63
#
#    ataque_especial  defensa_especial  velocidad  generacion  legendario
# 0               65                65         45           1       False
# 1               80                80         60           1       False

# %% [markdown]
# ### Breve detour, hablemos de pie plots...

# %%
pokemon
# Out:
#                     nombre   tipo_1  tipo_2  total  puntos_de_vida  ataque  \
# 0                Bulbasaur    Grass  Poison    318              45      49
# 1                  Ivysaur    Grass  Poison    405              60      62
# 2                 Venusaur    Grass  Poison    525              80      82
# 3    VenusaurMega Venusaur    Grass  Poison    625              80     100
# 4               Charmander     Fire     NaN    309              39      52
# ..                     ...      ...     ...    ...             ...     ...
# 795                Diancie     Rock   Fairy    600              50     100
# 796    DiancieMega Diancie     Rock   Fairy    700              50     160
# 797    HoopaHoopa Confined  Psychic   Ghost    600              80     110
# 798     HoopaHoopa Unbound  Psychic    Dark    680              80     160
# 799              Volcanion     Fire   Water    600              80     110
#
# ...

# %%
vc=  pokemon['generacion'].value_counts(normalize=True)*100
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(6,3))
ax[0].pie(vc.values, labels=vc.index)
ax[1].bar(height=vc.values, x=vc.index)
ax[0].set_title('Pocos insights')
ax[1].set_title('Muchos insights')
plt.plot()
### Vean como perdemos resolución si trabajamos con pie charts
# Out:
# []

# %%
pokemon['rango_ataque'] = np.where(pokemon['ataque']<40,"Débil",
         np.where(pokemon['ataque']>100,"Fuerte",
         "Medio")
         )
vc = pokemon['rango_ataque'].value_counts()
plt.pie(vc.values, labels=vc.index)
plt.title("Pie sirve bien en este caso (y muy pocos más)")
plt.plot()
# Out:
# []

# %% [markdown]
# ##### Hagamos Análisis Exploratorio. 🔍
#
# <li>¿Como se distribuyen los pokemones entre distintos tipos? </li>
# <li>¿Cúal es el pokemón más fuerte? ¿Y el más débil? </li>
# <li>¿Como se correlacionan las propiedades de ataque y defensa?</li>

# %%
(pokemon['tipo_1'].value_counts(normalize=True)*100).plot(kind='bar')
plt.title('Distribucion % por tipo 1')
plt.ylabel('%')
plt.show()

# %%
(pokemon['tipo_2'].value_counts(normalize=True)*100).plot(kind='bar',color='indianred')
plt.title('Distribucion % por tipo 2')
plt.ylabel('%')
plt.show()

# %%
pokemon['power'] = (pokemon['ataque'] * pokemon['defensa'] + 1.5 * (pokemon['ataque_especial'] + pokemon['defensa_especial'])) * pokemon['puntos_de_vida'] / 1000
pokemon.sort_values('power',ascending=False)
# Out:
#                       nombre    tipo_1  tipo_2  total  puntos_de_vida  ataque  \
# 424    GroudonPrimal Groudon    Ground    Fire    770             100     180
# 268  TyranitarMega Tyranitar      Rock    Dark    700             100     164
# 313                  Slaking    Normal     NaN    670             150     160
# 333        AggronMega Aggron     Steel     NaN    630              70     140
# 224      SteelixMega Steelix     Steel  Ground    610              75     125
# ..                       ...       ...     ...    ...             ...     ...
# 186                    Pichu  Electric     NaN    205              20      40
# 68                      Abra   Psychic     NaN    310              25      20
# 139                 Magikarp     Water     NaN    200              20      10
# 381                   Feebas     Water     NaN    200              20      15
# 316                 Shedinja       Bug   Ghost    236               1      90
#
# ...

# %%
cut = pokemon[['ataque','defensa','ataque_especial','defensa_especial']] #,'tipo_1'
sns.pairplot(cut) #,hue='tipo_1'
plt.show()

# %%
cut = pokemon[['ataque','defensa','ataque_especial','defensa_especial','tipo_1']]
sns.boxplot( data= cut,x="tipo_1", y="ataque" )
#ax = sns.stripplot(x='tipo_1', y='ataque', data=cut, color="red", jitter=0.2, size=2.5) #Para probar ver la distribución de los puntos, animate a descomentar esta línea
plt.xticks(rotation=90)
plt.title("Box plot de ataque según tipo_1")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,5),nrows=1,ncols=4,sharey=True)
axs = ax.flatten()
for prop, ax in zip(cut.columns[:-1],axs):
  sns.boxplot( data= cut,x="tipo_1", y=prop,ax=ax ) #violinplot animate a cambiar este boxplot por violinplot. Reflexioná sobre cual te trae más información y en que casos aplicar cada una
  ax.set_title(prop)
  ax.tick_params(labelrotation=90)

# %%
fig, ax = plt.subplots(figsize=(20,5),nrows=1,ncols=4,sharey=True)
axs = ax.flatten()
for prop, ax in zip(cut.columns[:-1],axs):
  sns.boxplot( data= cut,x="tipo_1", y=prop,ax=ax )
  ax.set_title(prop)
  ax.tick_params(labelrotation=90)

# %%
### Lolipop visualization

cut = pokemon.sample(10).sort_values('total').set_index('nombre') #Sampleo 10 para hacer la prueba
plt.hlines(y=cut.index, xmin=0, xmax=cut['total'], color='skyblue')
plt.xlabel("Puntos totales")
plt.plot(cut['total'], range(10), "o")
plt.title('Atributos totales por pokemon')
plt.plot()
# Out:
# []

# %%
pokemon =  get_my_data()
sns.set_theme(style="white")

# Generate a large random dataset

# Compute the correlation matrix


corr = pokemon.select_dtypes(exclude=['object']).drop(columns=['Total','#']).corr() ### TypeError: string dtypes are not allowed, use 'object' instead

# Mascara para solo graficar un triángulo
mask = np.triu(np.ones_like(corr, dtype=bool))


f, ax = plt.subplots(figsize=(11, 9))

# Generate un mapa de colores
cmap = sns.diverging_palette(100, 0, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,
            cmap=cmap,
            vmax=.3,
            center=0,
            square=True,
            linewidths=.5,
            cbar_kws={"shrink": .5},
            annot=True
            )
plt.title("Mapa de correlaciones de atributos de Pokemons")
# Out:
# Text(0.5, 1.0, 'Mapa de correlaciones de atributos de Pokemons')

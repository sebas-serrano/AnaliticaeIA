# %% [markdown]
# <h1> Manipulación de Datos en Python </h1>

# %% [markdown]
# Importamos pandas y creamos un dataFrame simple

# %%
import pandas as pd

df1 = pd.DataFrame(
     {
         "Nombre": ["Ana", "Pepe", "Hugo", "Maria"],
         "Apellido": ["Sanchez", "Lopez", "Hernandez", "Gonzalez"],
         "edad": ["26", "31", "9", "22"],
         "puesto": ["junior dev", "Senior dev", "Practicante", "PM"],
     },
     #index=[0, 1, 2, 3],
 )

# %%
df1
# Out:
#   Nombre   Apellido edad       puesto
# 0    Ana    Sanchez   26   junior dev
# 1   Pepe      Lopez   31   Senior dev
# 2   Hugo  Hernandez    9  Practicante
# 3  Maria   Gonzalez   22           PM

# %% [markdown]
# Seleccionamos a la gente con más de 25 años

# %%
df1[df1['edad'] > '25' ]
# Out:
#   Nombre   Apellido edad       puesto
# 0    Ana    Sanchez   26   junior dev
# 1   Pepe      Lopez   31   Senior dev
# 2   Hugo  Hernandez    9  Practicante

# %% [markdown]
# Otra opción de lograr este resultado, es pasar la edad a dato numérico, luego hacer el filtrado y eliminar los NaNs

# %%
df1['edad'] = pd.to_numeric(df1['edad'])

# %%
df1
# Out:
#   Nombre   Apellido  edad       puesto
# 0    Ana    Sanchez    26   junior dev
# 1   Pepe      Lopez    31   Senior dev
# 2   Hugo  Hernandez     9  Practicante
# 3  Maria   Gonzalez    22           PM

# %%
df1.dtypes
# Out:
# Nombre      object
# Apellido    object
# edad         int64
# puesto      object
# dtype: object

# %%
df1.where(df1['edad'] > 25)
# Out:
#   Nombre Apellido  edad      puesto
# 0    Ana  Sanchez  26.0  junior dev
# 1   Pepe    Lopez  31.0  Senior dev
# 2    NaN      NaN   NaN         NaN
# 3    NaN      NaN   NaN         NaN

# %%
df1.where(df1['edad'] > 25).dropna()
# Out:
#   Nombre Apellido  edad      puesto
# 0    Ana  Sanchez  26.0  junior dev
# 1   Pepe    Lopez  31.0  Senior dev

# %%
df1[df1['edad'] > 25]
# Out:
#   Nombre Apellido  edad      puesto
# 0    Ana  Sanchez    26  junior dev
# 1   Pepe    Lopez    31  Senior dev

# %%
df1
# Out:
#   Nombre   Apellido  edad       puesto
# 0    Ana    Sanchez    26   junior dev
# 1   Pepe      Lopez    31   Senior dev
# 2   Hugo  Hernandez     9  Practicante
# 3  Maria   Gonzalez    22           PM

# %%
df1.dtypes
# Out:
# Nombre      object
# Apellido    object
# edad         int64
# puesto      object
# dtype: object

# %% [markdown]
# Ahora la operación de proyección, (seleccionar solo algunas columnas)

# %%
df1[['Nombre', 'edad']]
# Out:
#   Nombre  edad
# 0    Ana    26
# 1   Pepe    31
# 2   Hugo     9
# 3  Maria    22

# %% [markdown]
# Ahora, juntándo las operaciones, primero la gente con más de 25 años, y luego solo su nombre y edad de ese resultado:

# %%
df1.where(df1['edad'] > 25).dropna()[['Nombre', 'edad']]
# Out:
#   Nombre  edad
# 0    Ana  26.0
# 1   Pepe  31.0

# %%
df1[df1['edad'] > 25][['Nombre', 'edad']]
# Out:
#   Nombre  edad
# 0    Ana    26
# 1   Pepe    31

# %% [markdown]
# Veamos un ejemplo de cómo hacer la operación de <h2>unión</h2> Utilizaremos la función concat de pandas para este fin.

# %%
df1 = pd.DataFrame(
     {
         "Nombre": ["Ana", "Pepe", "Hugo", "Maria"],
         "Apellido": ["Sanchez", "Lopez", "Hernandez", "Gonzalez"],
         "edad": ["26", "31", "19", "22"],
         "puesto": ["junior dev", "Senior dev", "Practicante", "PM"],
     },

 )


df2 = pd.DataFrame(
     {
         "Nombre": ["Raul", "Hector", "Hugo", "Maria"],
         "Apellido": ["Alvarez", "Rojas", "Hernandez", "Gonzalez"],
         "edad": ["41", "37", "19", "22"],
         "puesto": ["Senior dev", "Senior dev", "Practicante", "PM"],

     },

 )

# %%
df1
# Out:
#   Nombre   Apellido edad       puesto
# 0    Ana    Sanchez   26   junior dev
# 1   Pepe      Lopez   31   Senior dev
# 2   Hugo  Hernandez   19  Practicante
# 3  Maria   Gonzalez   22           PM

# %%
df2
# Out:
#    Nombre   Apellido edad       puesto
# 0    Raul    Alvarez   41   Senior dev
# 1  Hector      Rojas   37   Senior dev
# 2    Hugo  Hernandez   19  Practicante
# 3   Maria   Gonzalez   22           PM

# %%
df3 = pd.concat([df1, df2], ignore_index=True)

df3.drop_duplicates(inplace=True)

# %%
df3
# Out:
#    Nombre   Apellido edad       puesto
# 0     Ana    Sanchez   26   junior dev
# 1    Pepe      Lopez   31   Senior dev
# 2    Hugo  Hernandez   19  Practicante
# 3   Maria   Gonzalez   22           PM
# 4    Raul    Alvarez   41   Senior dev
# 5  Hector      Rojas   37   Senior dev

# %% [markdown]
# Para el operador de <h2>Diferencia</h2> no hay un operador, o una forma directa de hacerlo en pandas, pero se puede hacer de la siguiente manera:

# %%
pd.concat([df1, df2, df2])
# Out:
#    Nombre   Apellido edad       puesto
# 0     Ana    Sanchez   26   junior dev
# 1    Pepe      Lopez   31   Senior dev
# 2    Hugo  Hernandez   19  Practicante
# 3   Maria   Gonzalez   22           PM
# 0    Raul    Alvarez   41   Senior dev
# 1  Hector      Rojas   37   Senior dev
# 2    Hugo  Hernandez   19  Practicante
# 3   Maria   Gonzalez   22           PM
# 0    Raul    Alvarez   41   Senior dev
# 1  Hector      Rojas   37   Senior dev
# 2    Hugo  Hernandez   19  Practicante
# 3   Maria   Gonzalez   22           PM

# %% [markdown]
# Con la siguiente instrucción, tenemos a todos los elemento, quitando los duplicados, PERO, se conservan una vez los elementos que estaban repetidos

# %%
pd.concat([df1, df2, df2]).drop_duplicates()
# Out:
#    Nombre   Apellido edad       puesto
# 0     Ana    Sanchez   26   junior dev
# 1    Pepe      Lopez   31   Senior dev
# 2    Hugo  Hernandez   19  Practicante
# 3   Maria   Gonzalez   22           PM
# 0    Raul    Alvarez   41   Senior dev
# 1  Hector      Rojas   37   Senior dev

# %% [markdown]
# Si queremos que todos los repetidos se eliminen, podemos usar la siguiente instrucción

# %%
pd.concat([df2, df1, df2]).drop_duplicates(keep=False)
# Out:
#   Nombre Apellido edad      puesto
# 0    Ana  Sanchez   26  junior dev
# 1   Pepe    Lopez   31  Senior dev

# %%
pd.concat([df1, df2, df2]).drop_duplicates(keep=False)
# Out:
#   Nombre Apellido edad      puesto
# 0    Ana  Sanchez   26  junior dev
# 1   Pepe    Lopez   31  Senior dev

# %% [markdown]
# para el operador de <h2>Producto</h2> podemos hacerlo utilizando la función <b>merge</b> de pandas, de la siguiente manera :

# %%
left = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
right = pd.DataFrame({'col3': [5, 6]})

# %%
left
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
right
# Out:
#    col3
# 0     5
# 1     6

# %%
left.merge(right, how='cross')
# Out:
#    col1  col2  col3
# 0     1     3     5
# 1     1     3     6
# 2     2     4     5
# 3     2     4     6

# %%
df1.merge(df2, how='cross')
# Out:
#    Nombre_x Apellido_x edad_x     puesto_x Nombre_y Apellido_y edad_y  \
# 0       Ana    Sanchez     26   junior dev     Raul    Alvarez     41
# 1       Ana    Sanchez     26   junior dev   Hector      Rojas     37
# 2       Ana    Sanchez     26   junior dev     Hugo  Hernandez     19
# 3       Ana    Sanchez     26   junior dev    Maria   Gonzalez     22
# 4      Pepe      Lopez     31   Senior dev     Raul    Alvarez     41
# 5      Pepe      Lopez     31   Senior dev   Hector      Rojas     37
# 6      Pepe      Lopez     31   Senior dev     Hugo  Hernandez     19
# 7      Pepe      Lopez     31   Senior dev    Maria   Gonzalez     22
# 8      Hugo  Hernandez     19  Practicante     Raul    Alvarez     41
# 9      Hugo  Hernandez     19  Practicante   Hector      Rojas     37
# 10     Hugo  Hernandez     19  Practicante     Hugo  Hernandez     19
# 11     Hugo  Hernandez     19  Practicante    Maria   Gonzalez     22
# 12    Maria   Gonzalez     22           PM     Raul    Alvarez     41
# 13    Maria   Gonzalez     22           PM   Hector      Rojas     37
# 14    Maria   Gonzalez     22           PM     Hugo  Hernandez     19
# 15    Maria   Gonzalez     22           PM    Maria   Gonzalez     22
#
#        puesto_y
# 0    Senior dev
# 1    Senior dev
# 2   Practicante
# 3            PM
# 4    Senior dev
# 5    Senior dev
# 6   Practicante
# 7            PM
# 8    Senior dev
# 9    Senior dev
# 10  Practicante
# 11           PM
# 12   Senior dev
# 13   Senior dev
# 14  Practicante
# 15           PM

# %% [markdown]
# Aquí utilizamos la función merge de dataFrame para realizar la operación. Esta operación se comentará con un poco más de detalle más adelante

# %% [markdown]
# En algunos momentos puede ser útil el <h2>Renombrado</h2> de columnas. Puede ser solo para mostrar un dataframe (sin modificarlo), o puede ser que queramos realmente modificar el dataFrame

# %% [markdown]
# Veamos un ejemplo

# %%
df1
# Out:
#   Nombre   Apellido edad       puesto
# 0    Ana    Sanchez   26   junior dev
# 1   Pepe      Lopez   31   Senior dev
# 2   Hugo  Hernandez   19  Practicante
# 3  Maria   Gonzalez   22           PM

# %%
df1.columns = ['Name','lastname','age','position']
df1
# Out:
#     Name   lastname age     position
# 0    Ana    Sanchez  26   junior dev
# 1   Pepe      Lopez  31   Senior dev
# 2   Hugo  Hernandez  19  Practicante
# 3  Maria   Gonzalez  22           PM

# %%
df1.rename(columns={"Name": "nombre", "lastname": "apellido"})
# Out:
#   nombre   apellido age     position
# 0    Ana    Sanchez  26   junior dev
# 1   Pepe      Lopez  31   Senior dev
# 2   Hugo  Hernandez  19  Practicante
# 3  Maria   Gonzalez  22           PM

# %% [markdown]
# Intersección

# %%
df1.columns=df2.columns

# %%
df3 = df1.merge(df2)
df3
# Out:
#   Nombre   Apellido edad       puesto
# 0   Hugo  Hernandez   19  Practicante
# 1  Maria   Gonzalez   22           PM

# %% [markdown]
# Recordemos que merge por default funciona como un "inner join", así que con dataframes con esquemas compatibles, efectúa una intersección
